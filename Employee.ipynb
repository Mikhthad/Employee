# %% [markdown]
# # Data Description

# %% [markdown]
# •	EmployeeID: Unique identifier for each employee.
#
# •	FirstName: The first name of the employee.
#
# •	LastName: The last name of the employee.
#
# •	Gender: The gender of the employee.
#
# •	Age: The age of the employee.
#
# •	BusinessTravel: The frequency of business travel for the employee.
#
# •	Department: The department in which the employee works.
#
# •	DistanceFromHome (KM): The distance between the employee's home and workplace in kilometers.
#
# •	State: The state in which the employee resides.
#
# •	Ethnicity: The ethnicity of the employee.
#
# •	MaritalStatus: The marital status of the employee.•	Salary: The annual salary of the employee.
#
# •	StockOptionLevel: The level of stock options granted to the employee.
#
# •	OverTime: Whether the employee works overtime (Yes/No).
#
# •	HireDate: The date the employee was hired.
#
# •	Attrition: Whether the employee has left the company (Yes/No).
#
# •	YearsAtCompany: The number of years the employee has been with the company.
#
# •	YearsInMostRecentRole: The number of years the employee has been in their most recent role.
#
# •	YearsSinceLastPromotion: The number of years since the employee's last promotion.
#
# •	YearsWithCurrManager: The number of years the employee has worked with their current manager.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('Employee.csv')

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df.head()
# Out:
#   EmployeeID   FirstName LastName      Gender  Age BusinessTravel  \
# 0  3012-1A41    Leonelle    Simco      Female   30    Some Travel
# 1  CBCB-9C9D     Leonerd    Aland        Male   38    Some Travel
# 2  95D7-1CE9       Ahmed    Sykes        Male   43    Some Travel
# 3  47A0-559B  Ermentrude   Berrie  Non-Binary   39    Some Travel
# 4  42CC-040A       Stace   Savege      Female   29    Some Travel
#
#         Department  DistanceFromHome (KM) State                Ethnicity  ...  \
# 0            Sales                     27    IL                    White  ...
# 1            Sales                     23    CA                    White  ...
# 2  Human Resources                     29    CA  Asian or Asian American  ...
# 3       Technology                     12    IL                    White  ...
# 4  Human Resources                     29    CA                    White  ...
#
#    MaritalStatus  Salary StockOptionLevel OverTime    HireDate  Attrition  \
# ...

# %%
df.tail()
# Out:
#      EmployeeID FirstName     LastName      Gender  Age BusinessTravel  \
# 1465  467E-977A       Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624      Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928   Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9    Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3     Naoma      Hebbard      Female   20     No Travel
#
#       Department  DistanceFromHome (KM) State                  Ethnicity  ...  \
# 1465  Technology                     28    CA  Black or African American  ...
# 1466  Technology                      8    CA  Black or African American  ...
# 1467       Sales                      4    CA  Black or African American  ...
# 1468  Technology                      7    CA  Black or African American  ...
# 1469  Technology                     28    CA  Black or African American  ...
#
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               1470 non-null   object
#  1   FirstName                1470 non-null   object
#  2   LastName                 1470 non-null   object
#  3   Gender                   1470 non-null   object
#  4   Age                      1470 non-null   int64
#  5   BusinessTravel           1470 non-null   object
#  6   Department               1470 non-null   object
#  7   DistanceFromHome (KM)    1470 non-null   int64
#  8   State                    1470 non-null   object
#  9   Ethnicity                1470 non-null   object
#  10  Education                1470 non-null   int64
#  11  EducationField           1470 non-null   object
#  12  JobRole                  1470 non-null   object
#  13  MaritalStatus            1470 non-null   object
# ...

# %%
df.shape
# Out:
# (1470, 23)

# %%
df.size
# Out:
# 33810

# %%
df.describe().T
# Out:
#                           count           mean            std      min  \
# Age                      1470.0      28.989796       7.993055     18.0
# DistanceFromHome (KM)    1470.0      22.502721      12.811124      1.0
# Education                1470.0       2.912925       1.024165      1.0
# Salary                   1470.0  112956.497959  103342.889222  20387.0
# StockOptionLevel         1470.0       0.793878       0.852077      0.0
# YearsAtCompany           1470.0       4.562585       3.288048      0.0
# YearsInMostRecentRole    1470.0       2.293197       2.539093      0.0
# YearsSinceLastPromotion  1470.0       3.440816       2.945194      0.0
# YearsWithCurrManager     1470.0       2.239456       2.505774      0.0
#
#                              25%      50%        75%       max
# Age                         23.0     26.0      34.00      51.0
# DistanceFromHome (KM)       12.0     22.0      33.00      45.0
# Education                    2.0      3.0       4.00       5.0
# ...

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df[['Education','EducationField']]
# Out:
#       Education       EducationField
# 0             5            Marketing
# 1             4            Marketing
# 2             4           Marketing
# 3             3     Computer Science
# 4             2     Technical Degree
# ...         ...                  ...
# 1465          2     Computer Science
# 1466          3     Business Studies
# 1467          4            Marketing
# 1468          3  Information Systems
# 1469          2     Computer Science
#
# [1470 rows x 2 columns]

# %%
df[['EducationField','Education']][df['Education']==1]
# Out:
#            EducationField  Education
# 18       Computer Science          1
# 19              Economics          1
# 21       Technical Degree          1
# 30       Computer Science          1
# 34       Computer Science          1
# ...                   ...        ...
# 1410  Information Systems          1
# 1421            Marketing          1
# 1440            Economics          1
# 1444            Economics          1
# 1452     Computer Science          1
#
# [170 rows x 2 columns]

# %%
# change Hiredate types
df['HireDate'] = df['HireDate'].astype('datetime64[ns]')

# %%
df.dtypes
# Out:
# EmployeeID                         object
# FirstName                          object
# LastName                           object
# Gender                             object
# Age                                 int64
# BusinessTravel                     object
# Department                         object
# DistanceFromHome (KM)               int64
# State                              object
# Ethnicity                          object
# Education                           int64
# EducationField                     object
# JobRole                            object
# MaritalStatus                      object
# Salary                              int64
# StockOptionLevel                    int64
# OverTime                           object
# HireDate                   datetime64[ns]
# Attrition                          object
# YearsAtCompany                      int64
# YearsInMostRecentRole               int64
# YearsSinceLastPromotion             int64
# ...

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df.isna().sum()
# Out:
# EmployeeID                 0
# FirstName                  0
# LastName                   0
# Gender                     0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome (KM)      0
# State                      0
# Ethnicity                  0
# Education                  0
# EducationField             0
# JobRole                    0
# MaritalStatus              0
# Salary                     0
# StockOptionLevel           0
# OverTime                   0
# HireDate                   0
# Attrition                  0
# YearsAtCompany             0
# YearsInMostRecentRole      0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.nunique()
# Out:
# EmployeeID                 1470
# FirstName                  1334
# LastName                   1441
# Gender                        4
# Age                          34
# BusinessTravel                3
# Department                    3
# DistanceFromHome (KM)        45
# State                         3
# Ethnicity                     7
# Education                     5
# EducationField                9
# JobRole                      13
# MaritalStatus                 3
# Salary                     1455
# StockOptionLevel              4
# OverTime                      2
# HireDate                   1192
# Attrition                     2
# YearsAtCompany               11
# YearsInMostRecentRole        11
# YearsSinceLastPromotion      11
# YearsWithCurrManager         11
# dtype: int64

# %%
df.head()
# Out:
#   EmployeeID   FirstName LastName      Gender  Age BusinessTravel  \
# 0  3012-1A41    Leonelle    Simco      Female   30    Some Travel
# 1  CBCB-9C9D     Leonerd    Aland        Male   38    Some Travel
# 2  95D7-1CE9       Ahmed    Sykes        Male   43    Some Travel
# 3  47A0-559B  Ermentrude   Berrie  Non-Binary   39    Some Travel
# 4  42CC-040A       Stace   Savege      Female   29    Some Travel
#
#         Department  DistanceFromHome (KM) State                Ethnicity  ...  \
# 0            Sales                     27    IL                    White  ...
# 1            Sales                     23    CA                    White  ...
# 2  Human Resources                     29    CA  Asian or Asian American  ...
# 3       Technology                     12    IL                    White  ...
# 4  Human Resources                     29    CA                    White  ...
#
#    MaritalStatus  Salary StockOptionLevel OverTime   HireDate  Attrition  \
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df['Full_Name'] = df['FirstName']+' '+df['LastName']

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df['Year'] =df['HireDate'].dt.year
df['Month'] = df['HireDate'].dt.month
df['Month_Name'] = df['HireDate'].dt.month_name()
df['Day_Name'] = df['HireDate'].dt.day_name()

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df['FirstName'] = df['FirstName']+' '+df['LastName']

# %%
df.drop(['Full_Name','LastName'],axis =1,inplace = True)

# %%
df.rename({'FirstName':'Full_Name'},axis = 1,inplace =True)

# %%
df.head()
# Out:
#   EmployeeID          Full_Name      Gender  Age BusinessTravel  \
# 0  3012-1A41     Leonelle Simco      Female   30    Some Travel
# 1  CBCB-9C9D      Leonerd Aland        Male   38    Some Travel
# 2  95D7-1CE9        Ahmed Sykes        Male   43    Some Travel
# 3  47A0-559B  Ermentrude Berrie  Non-Binary   39    Some Travel
# 4  42CC-040A       Stace Savege      Female   29    Some Travel
#
#         Department  DistanceFromHome (KM) State                Ethnicity  \
# 0            Sales                     27    IL                    White
# 1            Sales                     23    CA                    White
# 2  Human Resources                     29    CA  Asian or Asian American
# 3       Technology                     12    IL                    White
# 4  Human Resources                     29    CA                    White
#
#    Education  ...   HireDate Attrition YearsAtCompany  YearsInMostRecentRole  \
# ...

# %%
# Q) Which employees over the age of 35 have been promoted within the last 5 years, and what are their current job roles?
df[['Full_Name','JobRole']][df['Age']>=35]
# Out:
#               Full_Name                   JobRole
# 1         Leonerd Aland           Sales Executive
# 2           Ahmed Sykes       HR Business Partner
# 3     Ermentrude Berrie       Engineering Manager
# 6            Uta Melmar       Engineering Manager
# 7          Joyan Brason           Sales Executive
# ...                 ...                       ...
# 1405       Erny Waywell  Senior Software Engineer
# 1418         Layton Ord           Sales Executive
# 1425     Doralia Vassie            Data Scientist
# 1436        Ava Galland              HR Executive
# 1463      Symon Raisher  Senior Software Engineer
#
# [353 rows x 2 columns]

# %%
# Q) which employees income greater than 100000
df[['Full_Name','Salary']][df['Salary']>=100000]
# Out:
#                 Full_Name  Salary
# 0          Leonelle Simco  102059
# 1           Leonerd Aland  157718
# 2             Ahmed Sykes  309964
# 3       Ermentrude Berrie  293132
# 5     Clerkclaude Hinkins  133468
# ...                   ...     ...
# 1453     Carlita Ivanenko  103429
# 1454       Jemie Tasseler  220896
# 1456      Spencer Gabitis  248259
# 1463        Symon Raisher  291663
# 1464         Laura Janiak  121414
#
# [531 rows x 2 columns]

# %%
# Q) Find all employees who work in the 'Sales' department:
df[df['Department']=='Sales']
# Out:
#      EmployeeID            Full_Name      Gender  Age      BusinessTravel  \
# 0     3012-1A41       Leonelle Simco      Female   30         Some Travel
# 1     CBCB-9C9D        Leonerd Aland        Male   38         Some Travel
# 5     C219-6C2E  Clerkclaude Hinkins        Male   34         Some Travel
# 7     3C7D-86ED         Joyan Brason      Female   40         Some Travel
# 8     3D71-8DC2     Alix Blazejewski        Male   38         Some Travel
# ...         ...                  ...         ...  ...                 ...
# 1444  C472-DAAD          Raf Laraway  Non-Binary   18  Frequent Traveller
# 1446  1CB3-F7D7      Janot Cicchillo      Female   21          No Travel
# 1457  06E8-4FD4        Emilee Wenham      Female   20         Some Travel
# 1464  CABE-0B62         Laura Janiak      Female   23         Some Travel
# 1467  EBF4-5928  Rudolph MacDearmont        Male   21         Some Travel
#
#      Department  DistanceFromHome (KM) State                        Ethnicity  \
# ...

# %%
# Q) Get the names and salaries of employees who have a stock option level greater than 1 using 
df.loc[df['StockOptionLevel']>1,['Full_Name','Salary']]
# Out:
#                  Full_Name  Salary
# 17            Cale Holston  108315
# 26            Rickey Shere   71201
# 37             Staci Leith  105984
# 44         Jaclin Chadburn   46514
# 56           Carlyn Pavese   82099
# ...                    ...     ...
# 1444           Raf Laraway   59962
# 1448          Layney Ratie   27760
# 1457         Emilee Wenham   38532
# 1460  Camellia Shelmerdine   35372
# 1466           Marc Calver   92995
#
# [243 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Full_Name', 'Gender', 'Age', 'BusinessTravel',
#        'Department', 'DistanceFromHome (KM)', 'State', 'Ethnicity',
#        'Education', 'EducationField', 'JobRole', 'MaritalStatus', 'Salary',
#        'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Year', 'Month', 'Month_Name', 'Day_Name'],
#       dtype='object')

# %%
# Q)display the first 5 rows of the dataset:
df.iloc[:5]
# Out:
#   EmployeeID          Full_Name      Gender  Age BusinessTravel  \
# 0  3012-1A41     Leonelle Simco      Female   30    Some Travel
# 1  CBCB-9C9D      Leonerd Aland        Male   38    Some Travel
# 2  95D7-1CE9        Ahmed Sykes        Male   43    Some Travel
# 3  47A0-559B  Ermentrude Berrie  Non-Binary   39    Some Travel
# 4  42CC-040A       Stace Savege      Female   29    Some Travel
#
#         Department  DistanceFromHome (KM) State                Ethnicity  \
# 0            Sales                     27    IL                    White
# 1            Sales                     23    CA                    White
# 2  Human Resources                     29    CA  Asian or Asian American
# 3       Technology                     12    IL                    White
# 4  Human Resources                     29    CA                    White
#
#    Education  ...   HireDate Attrition YearsAtCompany  YearsInMostRecentRole  \
# ...

# %%
# Q) Find the employee who has been with the current manager for the longest time*
df.loc[df['YearsWithCurrManager'].idxmax()]
# Out:
# EmployeeID                           DFA9-990E
# Full_Name                         Cale Holston
# Gender                                    Male
# Age                                         43
# BusinessTravel                      No Travel
# Department                               Sales
# DistanceFromHome (KM)                       34
# State                                       NY
# Ethnicity                                White
# Education                                    4
# EducationField                      Marketing
# JobRole                        Sales Executive
# MaritalStatus                          Married
# Salary                                  108315
# StockOptionLevel                             2
# OverTime                                    No
# HireDate                   2012-01-17 00:00:00
# Attrition                                   No
# YearsAtCompany                              10
# YearsInMostRecentRole                        9
# ...

# %%
# Q) Select employees who live more than 20 KM from their workplace and are less than 25 years old 
df.loc[(df['DistanceFromHome (KM)']>20) & (df['Age']<25)]
# Out:
#      EmployeeID             Full_Name             Gender  Age  \
# 556   8A5B-3D6E   Konstanze Scrammage             Female   24
# 561   3F0C-41A7         Mendie Readie               Male   24
# 573   1E61-B76A      Wilie Northfield             Female   24
# 583   B8A5-07A1       Ainsley Norheny             Female   24
# 584   2FAE-9278        Ettore Gorusso               Male   24
# ...         ...                   ...                ...  ...
# 1458  06B1-2653  Montgomery Galliford               Male   19
# 1461  85B2-41F5   Tessa De Cristoforo  Prefer Not To Say   19
# 1464  CABE-0B62          Laura Janiak             Female   23
# 1465  467E-977A         Jud Melanaphy               Male   20
# 1469  84D4-D4C3         Naoma Hebbard             Female   20
#
#           BusinessTravel  Department  DistanceFromHome (KM) State  \
# 556          Some Travel       Sales                     25    NY
# 561          Some Travel       Sales                     27    CA
# ...

# %%
# Q) Get the details of employees whose job role is 'Manager'
df.loc[df['JobRole']=='Manager']
# Out:
#      EmployeeID           Full_Name      Gender  Age      BusinessTravel  \
# 12    8BAB-B4A6         Torey Abram        Male   38         Some Travel
# 32    07B2-D67A    Rossie Everleigh        Male   44         Some Travel
# 43    2E72-4BF1        Grace Gohier        Male   44         Some Travel
# 52    11AE-3E4D      Sheffie Tonkin        Male   39         Some Travel
# 174   AB03-8820      Daryle Boarder        Male   43         Some Travel
# 188   6965-C170        Joya Hefford      Female   48         Some Travel
# 217   5021-95FC     Louie Trowsdall        Male   29         Some Travel
# 240   AB4A-E71A    Theodor Smaleman        Male   43         Some Travel
# 247   2E9A-BD2E  Blake Metheringham        Male   36         Some Travel
# 408   13E5-8466         Cody Tipple      Female   47         Some Travel
# 410   A7BB-F5A7  Anna-diana Horbart      Female   37         Some Travel
# 502   B102-5713        Adlai Pettit  Non-Binary   27         Some Travel
# ...

# %%
# select the 10th to 15th rows and the columns 'Full_Name', 'Age', and 'Department'
df.iloc[9:15,[1,3,5]]
# Out:
#           Full_Name  Age  Department
# 9      Kayley Snoad   31  Technology
# 10    Hannis Waslin   32  Technology
# 11  Annabela Pablos   35  Technology
# 12      Torey Abram   38       Sales
# 13      Edna Alison   37  Technology
# 14    Vernen Powner   33  Technology

# %%
#Q) Find all employees who were hired in the month of January
df.loc[df['Month_Name']=='January']
# Out:
#      EmployeeID            Full_Name      Gender  Age      BusinessTravel  \
# 0     3012-1A41       Leonelle Simco      Female   30         Some Travel
# 1     CBCB-9C9D        Leonerd Aland        Male   38         Some Travel
# 2     95D7-1CE9          Ahmed Sykes        Male   43         Some Travel
# 3     47A0-559B    Ermentrude Berrie  Non-Binary   39         Some Travel
# 4     42CC-040A         Stace Savege      Female   29         Some Travel
# ...         ...                  ...         ...  ...                 ...
# 1320  860E-0FA9       Zonda Lefeuvre      Female   18  Frequent Traveller
# 1321  7A98-768E  Ericha Tomczykowski      Female   18         Some Travel
# 1322  A5CD-8AB8     Hildagarde Marks      Female   18         Some Travel
# 1323  4268-9EAD        Hymie Jedryka        Male   24         Some Travel
# 1324  B324-A703          Cherri Lugg      Female   19         Some Travel
#
#            Department  DistanceFromHome (KM) State                Ethnicity  \
# ...

# %%
# Q1. Sort employees by their salary in descending order
df.sort_values(by= 'Salary', ascending=False)
# Out:
#      EmployeeID                 Full_Name      Gender  Age  \
# 385   17AE-E715            Norbie Mosdill        Male   31
# 397   DF63-0D3C               Roda Costin      Female   28
# 65    5731-90E6  Leonidas Clarke-Williams  Non-Binary   35
# 1167  1A7C-19DB              Randi Oswick      Female   39
# 1054  98EE-8547              Lock Pierson        Male   31
# ...         ...                       ...         ...  ...
# 334   45D7-5C8A             Artemus Boyet        Male   26
# 1111  D676-2084            Shannon Kuhnel        Male   21
# 1346  812D-7475            Lucius Plimmer        Male   20
# 1366  543B-0EE5       Theodore Parrington        Male   20
# 621   ADF8-AD57              Trip Bennell        Male   27
#
#           BusinessTravel       Department  DistanceFromHome (KM) State  \
# 385   Frequent Traveller       Technology                     38    CA
# 397   Frequent Traveller       Technology                     27    CA
# ...

# %%
# Q) Sort employees by their age in ascending order
df.sort_values(by= 'Age',ascending = True)
# Out:
#      EmployeeID          Full_Name      Gender  Age      BusinessTravel  \
# 1444  C472-DAAD        Raf Laraway  Non-Binary   18  Frequent Traveller
# 1376  E681-7B57      Durant Ratley        Male   18  Frequent Traveller
# 1415  6135-885F    Edeline Knevett      Female   18  Frequent Traveller
# 1428  5021-423E  Standford Dodshun        Male   18  Frequent Traveller
# 1374  32F1-6903    Mariya Mattheus      Female   18  Frequent Traveller
# ...         ...                ...         ...  ...                 ...
# 1006  200B-1979        Jamie Sarll        Male   50  Frequent Traveller
# 1280  C14B-814C   Roby Wintringham      Female   50  Frequent Traveller
# 1206  7B30-BAC8       Ferdy Geggus        Male   50  Frequent Traveller
# 1304  0C54-705D      Grata Yannoni      Female   50         Some Travel
# 1185  08AC-30AB     Wolf Sainsbury        Male   51         Some Travel
#
#       Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
# Q) Sort the dataset by 'YearsAtCompany' first and then by 'Salary', both in descending order
df[['YearsAtCompany','Salary']].sort_values(by = ['Salary'],ascending =False)
# Out:
#       YearsAtCompany  Salary
# 385                8  547204
# 397                8  546549
# 65                10  542695
# 1167               1  539998
# 1054               1  531629
# ...              ...     ...
# 334                2   20650
# 1111               2   20583
# 1346               0   20526
# 1366               0   20418
# 621                0   20387
#
# [1470 rows x 2 columns]

# %%
# Q)Sort employees by 'Department' alphabetically and then by 'HireDate' in ascending order
df[['Department','HireDate']].sort_values(by = ['Department','HireDate'],ascending = True)
# Out:
#            Department   HireDate
# 2     Human Resources 2012-01-04
# 4     Human Resources 2012-01-05
# 21    Human Resources 2012-01-19
# 23    Human Resources 2012-01-20
# 27    Human Resources 2012-01-25
# ...               ...        ...
# 1463       Technology 2022-12-18
# 1465       Technology 2022-12-26
# 1466       Technology 2022-12-30
# 1468       Technology 2022-12-30
# 1469       Technology 2022-12-31
#
# [1470 rows x 2 columns]

# %%
# Q)Sort the dataset by 'YearsSinceLastPromotion' in descending order
df.sort_values(by = 'YearsSinceLastPromotion' ,ascending = False)
# Out:
#      EmployeeID           Full_Name      Gender  Age BusinessTravel  \
# 101   085C-7FC2  Emmerich Wallicker        Male   47     No Travel
# 23    B3AF-7E58      Elvira Ianelli      Female   45    Some Travel
# 25    9E22-6287     Gifford Poynser  Non-Binary   48    Some Travel
# 26    D5DA-363A        Rickey Shere        Male   33    Some Travel
# 82    E5C1-B122       Camila Hernik      Female   36     No Travel
# ...         ...                 ...         ...  ...            ...
# 1264  D4FD-785B     Corina Bellwood      Female   19    Some Travel
# 815   4C99-E626  Friederike Wandrey      Female   25     No Travel
# 381   5160-53BD     Conrado Tomaini  Non-Binary   29    Some Travel
# 968   EAB1-2EB2     Giacinta Keasey      Female   21    Some Travel
# 1469  84D4-D4C3       Naoma Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State  \
# 101             Sales                     17    NY
# ...

# %%
# Q)Sort employees by 'Full_Name' in ascending alphabetical order
df.sort_values(by = 'Full_Name',ascending =True)
# Out:
#      EmployeeID         Full_Name  Gender  Age      BusinessTravel  \
# 1202  8B79-18F1      Abra MacGray  Female   20         Some Travel
# 804   0B19-EFB2        Ada Bynold  Female   39  Frequent Traveller
# 153   67ED-A630     Adan Fradgley    Male   29         Some Travel
# 763   FB4B-067E   Adan Sunderland  Female   31         Some Travel
# 1025  84D8-1A04    Adara Sleeford  Female   22         Some Travel
# ...         ...               ...     ...  ...                 ...
# 425   F5E3-48BB     Zenia Rattery  Female   25  Frequent Traveller
# 1320  860E-0FA9    Zonda Lefeuvre  Female   18  Frequent Traveller
# 115   F93D-CB5A   Zondra Duigenan  Female   40         Some Travel
# 20    D7EE-56FC    Zsa zsa Evered  Female   39  Frequent Traveller
# 666   6D3B-AD28  Zsa zsa Valentin  Female   25  Frequent Traveller
#
#            Department  DistanceFromHome (KM) State  \
# 1202       Technology                     39    CA
# 804        Technology                     25    CA
# ...

# %%
# Q) Sort employees by 'Ethnicity' and within each ethnic group, sort by 'Salary' in descending order
df[['Ethnicity','Salary']].sort_values(by =['Ethnicity','Salary'],ascending = [True,False])
# Out:
#                              Ethnicity  Salary
# 147   American Indian or Alaska Native  350525
# 24    American Indian or Alaska Native  328415
# 728   American Indian or Alaska Native  292386
# 857   American Indian or Alaska Native  251681
# 215   American Indian or Alaska Native  242890
# ...                                ...     ...
# 1377                             White   20778
# 1111                             White   20583
# 1346                             White   20526
# 1366                             White   20418
# 621                              White   20387
#
# [1470 rows x 2 columns]

# %%
# Q)Sort the dataset by 'DistanceFromHome (KM)' in ascending order and then by 'YearsWithCurrManager' in descending order
df[['DistanceFromHome (KM)','YearsWithCurrManager']].sort_values(by = ['DistanceFromHome (KM)','YearsWithCurrManager'],ascending = [True,False])
# Out:
#       DistanceFromHome (KM)  YearsWithCurrManager
# 19                        1                     9
# 99                        1                     9
# 424                       1                     7
# 627                       1                     6
# 455                       1                     5
# ...                     ...                   ...
# 1138                     45                     0
# 1210                     45                     0
# 1214                     45                     0
# 1368                     45                     0
# 1445                     45                     0
#
# [1470 rows x 2 columns]

# %% [markdown]
# isin

# %%
# Q)Find all employees who belong to the 'Sales' or 'Research & Development' departments and reset index
sales_rd_employees = df[df['Department'].isin(['Sales','Research & Development'])]
sales_rd_employees.reset_index(drop = True,inplace = True)
sales_rd_employees
# Out:
#     EmployeeID            Full_Name      Gender  Age      BusinessTravel  \
# 0    3012-1A41       Leonelle Simco      Female   30         Some Travel
# 1    CBCB-9C9D        Leonerd Aland        Male   38         Some Travel
# 2    C219-6C2E  Clerkclaude Hinkins        Male   34         Some Travel
# 3    3C7D-86ED         Joyan Brason      Female   40         Some Travel
# 4    3D71-8DC2     Alix Blazejewski        Male   38         Some Travel
# ..         ...                  ...         ...  ...                 ...
# 441  C472-DAAD          Raf Laraway  Non-Binary   18  Frequent Traveller
# 442  1CB3-F7D7      Janot Cicchillo      Female   21          No Travel
# 443  06E8-4FD4        Emilee Wenham      Female   20         Some Travel
# 444  CABE-0B62         Laura Janiak      Female   23         Some Travel
# 445  EBF4-5928  Rudolph MacDearmont        Male   21         Some Travel
#
#     Department  DistanceFromHome (KM) State                        Ethnicity  \
# ...

# %%
# Q)Select employees whose job roles are either 'Manager', 'Research Scientist', or 'Sales Executive'
job_roles=df[df['JobRole'].isin(['Manager','Research Scientist','Sales Executive'])]
job_roles.head()
# Out:
#   EmployeeID            Full_Name  Gender  Age BusinessTravel Department  \
# 0  3012-1A41       Leonelle Simco  Female   30    Some Travel      Sales
# 1  CBCB-9C9D        Leonerd Aland    Male   38    Some Travel      Sales
# 5  C219-6C2E  Clerkclaude Hinkins    Male   34    Some Travel      Sales
# 7  3C7D-86ED         Joyan Brason  Female   40    Some Travel      Sales
# 8  3D71-8DC2     Alix Blazejewski    Male   38    Some Travel      Sales
#
#    DistanceFromHome (KM) State                        Ethnicity  Education  \
# 0                     27    IL                            White          5
# 1                     23    CA                            White          4
# 5                     30    NY  Mixed or multiple ethnic groups          2
# 7                      3    CA                 Native Hawaiian           2
# 8                     20    IL        Black or African American          4
#
#    ...   HireDate Attrition YearsAtCompany  YearsInMostRecentRole  \
# ...

# %%
job_roles.reset_index(drop = True,inplace = True)
job_roles.head()
# Out:
#   EmployeeID            Full_Name  Gender  Age BusinessTravel Department  \
# 0  3012-1A41       Leonelle Simco  Female   30    Some Travel      Sales
# 1  CBCB-9C9D        Leonerd Aland    Male   38    Some Travel      Sales
# 2  C219-6C2E  Clerkclaude Hinkins    Male   34    Some Travel      Sales
# 3  3C7D-86ED         Joyan Brason  Female   40    Some Travel      Sales
# 4  3D71-8DC2     Alix Blazejewski    Male   38    Some Travel      Sales
#
#    DistanceFromHome (KM) State                        Ethnicity  Education  \
# 0                     27    IL                            White          5
# 1                     23    CA                            White          4
# 2                     30    NY  Mixed or multiple ethnic groups          2
# 3                      3    CA                 Native Hawaiian           2
# 4                     20    IL        Black or African American          4
#
#    ...   HireDate Attrition YearsAtCompany  YearsInMostRecentRole  \
# ...

# %%
# Q) Get all employees whose education field are 'Computer Science' then reset index 
filter_education = df[df['EducationField'].isin(['Computer Science'])]
filter_education.reset_index(drop = True,inplace = True)
filter_education.head()
# Out:
#   EmployeeID           Full_Name      Gender  Age      BusinessTravel  \
# 0  47A0-559B   Ermentrude Berrie  Non-Binary   39         Some Travel
# 1  73CF-4956       Hannis Waslin      Female   32         Some Travel
# 2  111D-E5EF         Edna Alison  Non-Binary   37         Some Travel
# 3  ED73-F078  Ernaline Napolione      Female   45  Frequent Traveller
# 4  9E22-6287     Gifford Poynser  Non-Binary   48         Some Travel
#
#    Department  DistanceFromHome (KM) State                Ethnicity  \
# 0  Technology                     12    IL                    White
# 1  Technology                     42    CA                    White
# 2  Technology                      3    IL                    White
# 3  Technology                     19    NY  Asian or Asian American
# 4  Technology                     37    CA                    White
#
#    Education  ...   HireDate Attrition YearsAtCompany  YearsInMostRecentRole  \
# ...

# %%
filter_education.set_index(['HireDate'])
# Out:
#            EmployeeID             Full_Name             Gender  Age  \
# HireDate
# 2012-01-05  47A0-559B     Ermentrude Berrie         Non-Binary   39
# 2012-01-12  73CF-4956         Hannis Waslin             Female   32
# 2012-01-15  111D-E5EF           Edna Alison         Non-Binary   37
# 2012-01-18  ED73-F078    Ernaline Napolione             Female   45
# 2012-01-21  9E22-6287       Gifford Poynser         Non-Binary   48
# ...               ...                   ...                ...  ...
# 2022-11-20  23B5-93C9      Carlita Ivanenko  Prefer Not To Say   31
# 2022-12-11  CB16-C876        April Beckwith             Female   19
# 2022-12-14  8A34-59DF  Camellia Shelmerdine         Non-Binary   19
# 2022-12-26  467E-977A         Jud Melanaphy               Male   20
# 2022-12-31  84D4-D4C3         Naoma Hebbard             Female   20
#
#                 BusinessTravel  Department  DistanceFromHome (KM) State  \
# HireDate
# ...

# %%
df1 = df.set_index(['Full_Name'])
df1
# Out:
#                     EmployeeID      Gender  Age BusinessTravel  \
# Full_Name
# Leonelle Simco       3012-1A41      Female   30    Some Travel
# Leonerd Aland        CBCB-9C9D        Male   38    Some Travel
# Ahmed Sykes          95D7-1CE9        Male   43    Some Travel
# Ermentrude Berrie    47A0-559B  Non-Binary   39    Some Travel
# Stace Savege         42CC-040A      Female   29    Some Travel
# ...                        ...         ...  ...            ...
# Jud Melanaphy        467E-977A        Male   20    Some Travel
# Marc Calver          6FB9-A624  Non-Binary   27    Some Travel
# Rudolph MacDearmont  EBF4-5928        Male   21    Some Travel
# Merill Agg           60E6-B1D9        Male   21    Some Travel
# Naoma Hebbard        84D4-D4C3      Female   20     No Travel
#
#                           Department  DistanceFromHome (KM) State  \
# Full_Name
# Leonelle Simco                 Sales                     27    IL
# ...

# %% [markdown]
# # Age Distribution of Employees

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', bins=20, kde=True)
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Gender Distribution across Departments

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Department', hue='Gender')
plt.title('Gender Distribution across Departments')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Attrition by Business Travel Frequency

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='BusinessTravel', hue='Attrition')
plt.title('Attrition by Business Travel Frequency')
plt.xlabel('Business Travel Frequency')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Stock Option Level vs. Attrition

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='StockOptionLevel', hue='Attrition')
plt.title('Stock Option Level vs. Attrition')
plt.xlabel('Stock Option Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Distance from Home vs. Attrition

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='DistanceFromHome (KM)', hue='Attrition', multiple='stack')
plt.title('Distance from Home vs. Attrition')
plt.xlabel('Distance from Home (KM)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Distribution of Years at Company by Marital Status

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='MaritalStatus', y='YearsAtCompany')
plt.title('Distribution of Years at Company by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Years at Company')
plt.show()

# %% [markdown]
# # Salary vs. Years at Company by Attrition

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='YearsAtCompany', y='Salary', hue='Attrition')
plt.title('Salary vs. Years at Company by Attrition')
plt.xlabel('Years at Company')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Suggestions:
# 1.Flexible Work Arrangements: To reduce attrition, especially among employees with high business travel frequency.
#
# 2.Diversity Initiatives: Establish programs for departments with low gender diversity to encourage inclusive hiring.
#
# 3.Retention Programs: Focus on employees with less tenure, as they may benefit from mentorship or development programs.
#
# 4.Salary Adjustments: Use insights from salary distributions to ensure competitive compensation across roles and tenures.

# %% [markdown]
# # Conclusion
# The analysis of the employee dataset reveals key trends and potential areas for improvement in the organization’s HR policies.
# Recommendations focus on improving retention, promoting diversity, and creating a supportive work environment for employees.
# Future analysis could include predictive modeling to anticipate attrition and identify high-risk employees for early intervention.
